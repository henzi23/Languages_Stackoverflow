# %% [markdown]
# # Investigation Program Languages Used by Developers
#
# The purpose of this analysis is to investigate what are the best programming languages to learn to be a Developer. For this analysis we utilize survey results from StackOverflow.  The results of this analysis will be utilzied to write a blog post.  As such we will create clean charts to be utilzied in this blog.

# %% [markdown]
# ### Initial load
#
# Packages are imported.  Additionally the survey data will be loaded from a flat file obtained and downloaded to my local drive from Kaggle (https://www.kaggle.com/stackoverflow/so-survey-2017).

# %%
# Import packages
import numpy as np
import pandas as pd
from collections import defaultdict
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
# load and check survey data
df = pd.read_csv('./survey_results_public.csv')
df.head()
# Out:
#    Respondent                                       Professional  \
# 0           1                                            Student
# 1           2                                            Student
# 2           3                             Professional developer
# 3           4  Professional non-developer who sometimes write...
# 4           5                             Professional developer
#
#                 ProgramHobby         Country      University  \
# 0                  Yes, both   United States              No
# 1                  Yes, both  United Kingdom  Yes, full-time
# 2                  Yes, both  United Kingdom              No
# 3                  Yes, both   United States              No
# 4  Yes, I program as a hobby     Switzerland              No
#
#                          EmploymentStatus  \
# 0  Not employed, and not looking for work
# 1                      Employed part-time
# 2                      Employed full-time
# ...

# %%
# Load and check schema info
schema = pd.read_csv('./survey_results_schema.csv')
schema.head()
# Out:
#          Column                                           Question
# 0    Respondent                               Respondent ID number
# 1  Professional         Which of the following best describes you?
# 2  ProgramHobby  Do you program as a hobby or contribute to ope...
# 3       Country            In which country do you currently live?
# 4    University  Are you currently enrolled in a formal, degree...

# %% [markdown]
# ### Investigate
# Now that the data files are loaded let's investigate columns that might help us understand programming languages used by Professional Developers.

# %%
# Use Schema to find columns related to Languages

schema[schema["Question"].str.contains("language")]
# Out:
#                 Column                                           Question
# 53       AssessJobTech  When you're assessing potential jobs to apply ...
# 88  HaveWorkedLanguage  Which of the following languages have you done...
# 89    WantWorkLanguage  Which of the following languages have you done...

# %% [markdown]
# Rows 88 and 89 look like they might be promising.  Let's check the full question text

# %%
print(schema.iloc[88,1])
print(schema.iloc[89,1])
# Out:
# Which of the following languages have you done extensive development work in over the past year, and which do you want to work in over the next year?
# Which of the following languages have you done extensive development work in over the past year, and which do you want to work in over the next year?

# %% [markdown]
# These look like they can help us answer our question.  Let's take a deeper look into what the entries look like.

# %%
# Get value counts for HaveWorkedLanguage
df.HaveWorkedLanguage.value_counts()
# Out:
# C#; JavaScript; SQL                                                                                       1276
# JavaScript; PHP; SQL                                                                                      1143
# Java                                                                                                       913
# JavaScript                                                                                                 807
# JavaScript; PHP                                                                                            662
# Java; JavaScript; SQL                                                                                      645
# Java; JavaScript                                                                                           585
# C#                                                                                                         540
# ...

# %%
# Get value counts for WantWorkLanguage
df.WantWorkLanguage.value_counts()
# Out:
# JavaScript                                                     642
# Python                                                         556
# Java                                                           544
# C#                                                             475
# C#; JavaScript; SQL                                            444
# Java; JavaScript                                               332
# C#; JavaScript; SQL; TypeScript                                326
# JavaScript; PHP; SQL                                           324
# C++                                                            317
# Swift                                                          306
# JavaScript; Python                                             300
# C#; SQL                                                        280
# C#; JavaScript                                                 268
# Java; JavaScript; SQL                                          224
# ...

# %% [markdown]
# Both columns utilzie a semicolon seperated format.  We will need break this into a list or something we can better work with.  Examining the specific entries, it looks like consistent namign conventions are used for the languages (capitalization, etc).  However it looks like some entries have leading spaces and some do not.  We will have to account for that in our cleaning.
#
# Let's also check for missing values

# %%
# Check for missing values and total number of entries
print("Missinng entries:")
print(df[['HaveWorkedLanguage','WantWorkLanguage']].isnull().sum(axis=0))
print("Total Entries:       ",df.shape[0])
# Out:
# Missinng entries:
# HaveWorkedLanguage    14767
# WantWorkLanguage      17621
# dtype: int64
# Total Entries:        51392

# %% [markdown]
# Seems we have a large percentage of missing entries in the Language columns.  However, looking at entries in other columns this might be because we have entries from people that are not Developers or are not employed.  Since we want to to focus on what langauge employed, Professional Developers use, we should subset the data.

# %%
# subset data to Professional Developer and employed full time.  Then check for NAs
df_prof_emp = df[(df['Professional']=="Professional developer") & (df['EmploymentStatus']=="Employed full-time")]
print('Missing entries from employed, Professional developers:')
print(df_prof_emp[['HaveWorkedLanguage','WantWorkLanguage']].isnull().sum(axis=0))
print('Total entries:      ',df_prof_emp.shape[0])
# Out:
# Missing entries from employed, Professional developers:
# HaveWorkedLanguage    7285
# WantWorkLanguage      9180
# dtype: int64
# Total entries:       30211

# %% [markdown]
# Well, even within the subset we see a high rate of missing entries.  Since it seems logical that employed, professional developers would have languages they program in and want to program in, we can assume these missing values are because of people skippng this question.  In any case we will exclude these entries as it doesn't make sense to extrapolate them.
#
# In addition to knowing what languages developers are using and want to use it would be interesting if this distribution changes based on years of working in coding jobs.  For example is there a difference in programming language choices between long tenured programmers verses those that are newer to programming.  To help in understanding this we can look at the column YearsCodedJob.

# %%
# Get value counts for YearsCodedJob
df_prof_emp.YearsCodedJob.value_counts()
# Out:
# 1 to 2 years        3542
# 2 to 3 years        3539
# 3 to 4 years        3071
# 4 to 5 years        2589
# 5 to 6 years        2339
# 20 or more years    2084
# Less than a year    1761
# 6 to 7 years        1526
# 9 to 10 years       1435
# 7 to 8 years        1321
# 10 to 11 years      1287
# 8 to 9 years        1033
# 11 to 12 years       657
# 15 to 16 years       608
# 14 to 15 years       592
# 12 to 13 years       586
# 16 to 17 years       543
# 17 to 18 years       425
# 13 to 14 years       420
# 19 to 20 years       323
# 18 to 19 years       297
# Name: YearsCodedJob, dtype: int64

# %% [markdown]
# The column has quite a few categories.  For analysis I'd liek to decrease this to only a few:
# * New : 0-3 years
# * Mid : 3-10 years
# * Experienced : >10 years
#
# Thus we is need to recode the column.

# %%
# Recode YearsCodedJob

# Create a dictionary for the recoding
recode_dict = {'1 to 2 years':'New', '2 to 3 years':'New', 'Less than a year':'New',
               '3 to 4 years':'Mid','4 to 5 years':'Mid','5 to 6 years':'Mid',
               '6 to 7 years':'Mid','7 to 8 years':'Mid','8 to 9 years':'Mid',
               '9 to 10 years':'Mid','10 to 11 years':'Experienced','11 to 12 years':'Experienced',
               '12 to 13 years':'Experienced','13 to 14 years':'Experienced',
               '14 to 15 years':'Experienced','15 to 16 years':'Experienced',
               '16 to 17 years':'Experienced','17 to 18 years':'Experienced',
               '18 to 19 years':'Experienced','19 to 20 years':'Experienced',
               '20 or more years':'Experienced'}

# Recode
df_prof_emp['YearsCodedJob'].replace(recode_dict,inplace=True)

# Check result
df_prof_emp.YearsCodedJob.value_counts()
# Out:
# C:\Users\jhenzi\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\core\generic.py:4619: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self._update_inplace(new_data)
# Mid            13314
# New             8842
# Experienced     7822
# Name: YearsCodedJob, dtype: int64

# %% [markdown]
# The recoding looks successful.  Now that we have our updated dataset, Let's move into analysis.

# %% [markdown]
# ## Analysis
#
# The analysis will center around answering 3 questions:
# * Question 1: What programming languages do professional developers most commonly use?
# * Question 2: What programming languages do professional developers want to use in the next year?
# * Question 3: Does the amount of experience (years in coding job) affect the distribution for commonly used and want to use programming language?
#
#
# ### Question 1: What programming languages do professional developers most commonly use?
# We will analyze the HaveWorkedLanguage column to gain understanding about what languages have been utilized by employed, professional developers.  We will start by breaking down the semicolon seperated entries into lists.  Then add up number of rows are calling out each language.

# %%
# Function to get counts of entries by programming language

def language_counts(df,col):
    '''
    Function to get counts of entries that answered each programming langauage.
    
    Inputs:
        df- pandas dataframe with survey data
        col- string with name of column to be investigated
    
    Outputs:
        pandas dataframe with columns for language, count of entries, and % of entries
            sorted by counts.
    '''
    
    # split string of entries into list of langauges
    df[col] = df[col].str.replace(' ','')
    val_count = df[col].value_counts().reset_index()
    val_count['index'] = val_count['index'].str.split(';')
    
    # create list of unique language entries
    entries = val_count['index'].tolist()
    entries = [item for items in entries for item in items]  #un-nest list of lists
    entries = list(set(entries))
    
    out_df = defaultdict(int)
    
    #loop through Languages
    for language in entries:
        for idx in range(val_count.shape[0]):
            if language in val_count['index'][idx]:
                out_df[language] += int(val_count[col][idx])
    out_df = pd.DataFrame(pd.Series(out_df)).reset_index()
    out_df.columns = ["Language","Count"]
    out_df['Percent'] = out_df.Count/df[col].count() * 100
    out_df.sort_values("Count",ascending=False, inplace=True)
    return out_df

# %%
# Get language counts for HaveWorkedLanguage
have_worked = language_counts(df_prof_emp,col='HaveWorkedLanguage')
have_worked
# Out:
# C:\Users\jhenzi\AppData\Local\Continuum\anaconda3\lib\site-packages\ipykernel\__main__.py:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#         Language  Count    Percent
# 16    JavaScript  15226  66.413679
# 27           SQL  12336  53.807904
# 15          Java   8793  38.353834
# 2             C#   8628  37.634127
# 23        Python   6235  27.196196
# 21           PHP   5821  25.390386
# 3            C++   4236  18.476839
# 1              C   3306  14.420309
# 31    TypeScript   2561  11.170723
# 25          Ruby   2156   9.404170
# 20   Objective-C   1577   6.878653
# 30         Swift   1463   6.381401
# 32        VB.NET   1414   6.167670
# 11            Go   1041   4.540696
# 28         Scala    950   4.143767
# ...

# %% [markdown]
# The breakdown of counts by programming language is shown above.  Unsurprisingly we see that Java, SQL, C, and Python near the top.  Let's plot the data to be a bit more visually appealing and for ease of comparisons.

# %%
# plot the top 20
plt.rcParams["figure.figsize"]=10,5

plt.bar(have_worked.Language[0:20],have_worked.Percent[0:20])
plt.xticks(rotation=65)
plt.ylabel("% of respondents")
plt.title("Top 20 Languages Used by Developers",size=20);

plt.savefig('use.jpg', bbox_inches='tight')

# %% [markdown]
# ### Question 2: What programming languages do professional developers want to use in the next year?
#
# We will now analyze the WantWorkLanguage in a similar fashion as HaveWorkedLanguage to gain an understanding of the languages developers want to use in the next year.

# %%
# Get language counts for WantWorkLanguage
want_work = language_counts(df_prof_emp,col='WantWorkLanguage')
want_work
# Out:
# C:\Users\jhenzi\AppData\Local\Continuum\anaconda3\lib\site-packages\ipykernel\__main__.py:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#         Language  Count    Percent
# 16    JavaScript  10581  50.311445
# 27           SQL   7093  33.726404
# 23        Python   7000  33.284200
# 2             C#   6776  32.219105
# 15          Java   5913  28.115639
# 31    TypeScript   4241  20.165470
# 3            C++   3931  18.691455
# 11            Go   3837  18.244496
# 30         Swift   2841  13.508630
# 21           PHP   2763  13.137749
# 1              C   2346  11.154962
# 25          Ruby   2342  11.135942
# 28         Scala   2134  10.146926
# 26          Rust   1763   8.382863
# 10            F#   1527   7.260710
# ...

# %% [markdown]
# Again we see Java, SQL, C, and Python near the top, but now we see some other languages like TypeScript and Go moving up the list.  As before we will plot the data.

# %%
# PLot Top 20
plt.rcParams["figure.figsize"]=10,5

plt.bar(want_work.Language[0:20],want_work.Percent[0:20])
plt.xticks(rotation=65)
plt.ylabel("% of respondents")
plt.title("Top 20 Developers Want to Use",size=20);

plt.savefig('want.jpg', bbox_inches='tight')

# %% [markdown]
# ### Question 3: Does the amount of experience (years in coding job) affect the distribution for commonly used and want to use programming language?
#
# To answer this question we will combine analysis like that done for question 1 and 2 broken down by our recoded column YearsCodedJob.

# %%
# Analyze HaveWorkedLanguage by experience

# Create function to generate language counts by experience

def language_counts_experience(df,col,experience):
    '''
    Function to get counts of entries that answered each programming langauage by 
    groupings from YearsCodedJob.
    
    Inputs:
        df- pandas dataframe with survey data
        col- string with name of column to be investigated
        experience - grouping from column YearsCodedJob to analyze
    
    Outputs:
        pandas dataframe with columns for language, count of entries, and % of entries
            sorted ascending by percent.
    '''
    exp_df = df[df.YearsCodedJob == experience]
    output = language_counts(exp_df,col)
    output.sort_values("Percent",ascending=True, inplace=True)
    return output

# %%
# Analyze HaveWorkedLanguage by experience

new_have_worked = language_counts_experience(df_prof_emp,'HaveWorkedLanguage','New')
mid_have_worked = language_counts_experience(df_prof_emp,'HaveWorkedLanguage','Mid')
experienced_have_worked = language_counts_experience(df_prof_emp,'HaveWorkedLanguage','Experienced')
# Out:
# C:\Users\jhenzi\AppData\Local\Continuum\anaconda3\lib\site-packages\ipykernel\__main__.py:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %% [markdown]
# To help analyze we will plot these three next to each other.

# %%
# Plot HaveWorkedLanguage by experience

fig, ax = plt.subplots(ncols=3, figsize=(15,5))

fig.suptitle("Programming Languages Used by Developers by Coding Experience",size=20)
fig.subplots_adjust(top=0.85)
fig.subplots_adjust(wspace=0.5)

new_have_worked[-10:].plot.barh(x='Language',y='Percent',color='c',legend=False, ax=ax[0])
ax[0].set_title('0-3 yrs in coding job')
ax[0].set_xlabel('% of respondents')
ax[0].set_ylabel('')

mid_have_worked[-10:].plot.barh(x='Language',y='Percent',color='c',legend=False, ax=ax[1])
ax[1].set_title('0-10 yrs in coding job')
ax[1].set_xlabel('% of respondents')
ax[1].set_ylabel('')

experienced_have_worked[-10:].plot.barh(x='Language',y='Percent',color='c',legend=False, ax=ax[2])
ax[2].set_title('10 or more years in coding job')
ax[2].set_xlabel('% of respondents')
ax[2].set_ylabel('');

plt.savefig('used_by_experience.jpg', bbox_inches='tight')

# %% [raw]
# The chart makes it clear to see there is little difference in languages used ranking between the expereince groupings.  With the exception of PHP we only see the ranking change by one level.  Additionally we note the percentages of respondents calling out each language is fairly tight.
#
# Maybe we'll see bigger differences when we compare the wat to use languages for each experience grouping.

# %%
# Analyze WantWorkLanguage by experience

new_want_work = language_counts_experience(df_prof_emp,'WantWorkLanguage','New')
mid_want_work  = language_counts_experience(df_prof_emp,'WantWorkLanguage','Mid')
experienced_want_work  = language_counts_experience(df_prof_emp,'WantWorkLanguage','Experienced')
# Out:
# C:\Users\jhenzi\AppData\Local\Continuum\anaconda3\lib\site-packages\ipykernel\__main__.py:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %% [markdown]
# Let's plot the results to get a visual comparison.

# %%
# Plot WantWorkLanguage by experience

fig, ax = plt.subplots(ncols=3, figsize=(15,5))

fig.suptitle("Programming Languages Want to be Used by Coding Experience",size=20)
fig.subplots_adjust(top=0.85)
fig.subplots_adjust(wspace=0.5)

new_want_work[-10:].plot.barh(x='Language',y='Percent',color='c',legend=False, ax=ax[0])
ax[0].set_title('0-3 yrs in coding job')
ax[0].set_xlabel('% of respondents')
ax[0].set_ylabel('')

mid_want_work[-10:].plot.barh(x='Language',y='Percent',color='c',legend=False, ax=ax[1])
ax[1].set_title('0-10 yrs in coding job')
ax[1].set_xlabel('% of respondents')
ax[1].set_ylabel('')

experienced_want_work[-10:].plot.barh(x='Language',y='Percent',color='c',legend=False, ax=ax[2])
ax[2].set_title('10 or more years in coding job')
ax[2].set_xlabel('% of respondents')
ax[2].set_ylabel('');

plt.savefig('want_by_experience.jpg', bbox_inches='tight')

# %% [markdown]
# Again we do not see any major shifts.  We do see some minor trends like Python shows higher for developers with less than 10 years of coding job expereince.  Additionally less propensity towards C# with less experience.  For all groupings we see some newer languages like Go and Swift showing up.

# %% [markdown]
# References:
# * https://stackoverflow.com/questions/20112776/how-do-i-flatten-a-list-of-lists-nested-lists
# * https://stackoverflow.com/questions/9622163/save-plot-to-image-file-instead-of-displaying-it-using-matplotlib
